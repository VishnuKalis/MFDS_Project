# %%
import pandas as pd
import numpy as num
from matplotlib import pyplot as plt
state_df = pd.read_csv('covid_19_india.csv',parse_dates=['Date'])
plt.figure()
Kerala_df = state_df[state_df['State/UnionTerritory'] == 'Kerala']
Kerala_df[['Cured','Deaths','Confirmed']].plot(title="Kerala")
plt.xlabel("Date as S.No")
plt.ylabel("No. of cases per day")
Goa_df = state_df[state_df['State/UnionTerritory'] == 'Goa']
Goa_df[['Cured','Deaths','Confirmed']].plot(title="Goa")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Delhi_df = state_df[state_df['State/UnionTerritory'] == 'Delhi']
Delhi_df[['Cured','Deaths','Confirmed']].plot(title="Delhi")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
AndhraPradesh_df = state_df[state_df['State/UnionTerritory'] == 'Andhra Pradesh']
AndhraPradesh_df[['Cured','Deaths','Confirmed']].plot(title="Andhra Pradesh")
plt.xlabel("Date as S.No")
plt.ylabel("No. of cases per day")
Andaman_df = state_df[state_df['State/UnionTerritory'] == 'Andaman and Nicobar Islands']
Andaman_df[['Cured','Deaths','Confirmed']].plot(title="Andaman and Nicobar Islands")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
ArunachalPradesh_df = state_df[state_df['State/UnionTerritory'] == 'Arunachal Pradesh']
ArunachalPradesh_df[['Cured','Deaths','Confirmed']].plot(title="Arunachal Pradesh")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Assam_df = state_df[state_df['State/UnionTerritory'] == 'Assam']
Assam_df[['Cured','Deaths','Confirmed']].plot(title="Assam")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Bihar_df = state_df[state_df['State/UnionTerritory'] == 'Bihar']
Bihar_df[['Cured','Deaths','Confirmed']].plot(title="Bihar")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Chandigarh_df = state_df[state_df['State/UnionTerritory'] == 'Chandigarh']
Chandigarh_df[['Cured','Deaths','Confirmed']].plot(title="Chandigarh")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Chhattisgarh_df = state_df[state_df['State/UnionTerritory'] == 'Chhattisgarh']
Chhattisgarh_df[['Cured','Deaths','Confirmed']].plot(title="Chhattisgarh")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Gujarat_df = state_df[state_df['State/UnionTerritory'] == 'Gujarat']
Gujarat_df[['Cured','Deaths','Confirmed']].plot(title="Gujarat")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Haryana_df = state_df[state_df['State/UnionTerritory'] == 'Haryana']
Haryana_df[['Cured','Deaths','Confirmed']].plot(title="Haryana")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Himachal_df = state_df[state_df['State/UnionTerritory'] == 'Himachal Pradesh']
Himachal_df[['Cured','Deaths','Confirmed']].plot(title="Himachal Pradesh")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
JK_df = state_df[state_df['State/UnionTerritory'] == 'Jammu and Kashmir']
JK_df[['Cured','Deaths','Confirmed']].plot(title="Jammu and Kashmir")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Jharkhand_df = state_df[state_df['State/UnionTerritory'] == 'Jharkhand']
Jharkhand_df[['Cured','Deaths','Confirmed']].plot(title="Jharkhand")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Karnataka_df = state_df[state_df['State/UnionTerritory'] == 'Karnataka']
Karnataka_df[['Cured','Deaths','Confirmed']].plot(title="Karnataka")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Ladakh_df = state_df[state_df['State/UnionTerritory'] == 'Ladakh']
Ladakh_df[['Cured','Deaths','Confirmed']].plot(title="Ladakh")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
MP_df = state_df[state_df['State/UnionTerritory'] == 'Madhya Pradesh']
MP_df[['Cured','Deaths','Confirmed']].plot(title="Madhya Pradesh")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Maharashtra_df = state_df[state_df['State/UnionTerritory'] == 'Maharashtra']
Maharashtra_df[['Cured','Deaths','Confirmed']].plot(title="Maharashtra")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Manipur_df = state_df[state_df['State/UnionTerritory'] == 'Manipur']
Manipur_df[['Cured','Deaths','Confirmed']].plot(title="Manipur")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Mizoram_df = state_df[state_df['State/UnionTerritory'] == 'Mizoram']
Mizoram_df[['Cured','Deaths','Confirmed']].plot(title="Mizoram")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Odisha_df = state_df[state_df['State/UnionTerritory'] == 'Odisha']
Odisha_df[['Cured','Deaths','Confirmed']].plot(title="Odisha")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Puducherry_df = state_df[state_df['State/UnionTerritory'] == 'Puducherry']
Puducherry_df[['Cured','Deaths','Confirmed']].plot(title="Puducherry")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Punjab_df = state_df[state_df['State/UnionTerritory'] == 'Punjab']
Punjab_df[['Cured','Deaths','Confirmed']].plot(title="Punjab")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Rajasthan_df = state_df[state_df['State/UnionTerritory'] == 'Rajasthan']
Rajasthan_df[['Cured','Deaths','Confirmed']].plot(title="Rajasthan")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
TN_df = state_df[state_df['State/UnionTerritory'] == 'Tamil Nadu']
TN_df[['Cured','Deaths','Confirmed']].plot(title="Tamil Nadu")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
TS_df = state_df[state_df['State/UnionTerritory'] == 'Telengana']
TS_df[['Cured','Deaths','Confirmed']].plot(title="Telengana")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Tripura_df = state_df[state_df['State/UnionTerritory'] == 'Tripura']
Tripura_df[['Cured','Deaths','Confirmed']].plot(title="Tripura")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
UP_df = state_df[state_df['State/UnionTerritory'] == 'Uttar Pradesh']
UP_df[['Cured','Deaths','Confirmed']].plot(title="Uttar Pradesh")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
Uttarakhand_df = state_df[state_df['State/UnionTerritory'] == 'Uttarakhand']
Uttarakhand_df[['Cured','Deaths','Confirmed']].plot(title="Uttarakhand")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
WB_df = state_df[state_df['State/UnionTerritory'] == 'West Bengal']
WB_df[['Cured','Deaths','Confirmed']].plot(title="West Bengal")
plt.xlabel("Date as S.no")
plt.ylabel("No. of cases per day")
# Out:
# C:\Users\ksvcr\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# C:\Users\ksvcr\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...
