# %%
import pandas as pd
data1 = pd.read_csv("AgeGroupDetails.csv")
data2 = pd.read_csv("covid_19_india.csv")
data3 = pd.read_csv("HospitalBedsIndia.csv")
data4 = pd.read_csv("ICMRTestingDetails.csv")
data5 = pd.read_csv("IndividualDetails.csv")
data6 = pd.read_csv("population_india_census2011.csv")
data7 = pd.read_csv("ICMRTestingLabs.csv")
data2
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0      1  30/01/20  6:00 PM               Kerala                       1
# 1      2  31/01/20  6:00 PM               Kerala                       1
# 2      3  01/02/20  6:00 PM               Kerala                       2
# 3      4  02/02/20  6:00 PM               Kerala                       3
# 4      5  03/02/20  6:00 PM               Kerala                       3
# ..   ...       ...      ...                  ...                     ...
# 734  735  07/04/20  9:00 AM            Telengana                       -
# 735  736  07/04/20  9:00 AM              Tripura                       -
# 736  737  07/04/20  9:00 AM          Uttarakhand                       -
# 737  738  07/04/20  9:00 AM        Uttar Pradesh                       -
# 738  739  07/04/20  9:00 AM          West Bengal                       -
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
data2[['State/UnionTerritory','Confirmed']]
len(set(data2['State/UnionTerritory']))
# Out:
# 32

# %%
len(set(data5['notes']))
# Out:
# 616

# %%
data2
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0      1  30/01/20  6:00 PM               Kerala                       1
# 1      2  31/01/20  6:00 PM               Kerala                       1
# 2      3  01/02/20  6:00 PM               Kerala                       2
# 3      4  02/02/20  6:00 PM               Kerala                       3
# 4      5  03/02/20  6:00 PM               Kerala                       3
# ..   ...       ...      ...                  ...                     ...
# 734  735  07/04/20  9:00 AM            Telengana                       -
# 735  736  07/04/20  9:00 AM              Tripura                       -
# 736  737  07/04/20  9:00 AM          Uttarakhand                       -
# 737  738  07/04/20  9:00 AM        Uttar Pradesh                       -
# 738  739  07/04/20  9:00 AM          West Bengal                       -
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
sorted(list(set(data2['Confirmed'])))
data5
# Out:
#         id government_id diagnosed_date  age gender             detected_city  \
# 0        0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1        1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2        2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3        3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4        4         TS-P1     02/03/2020   24      M                 Hyderabad
# ...    ...           ...            ...  ...    ...                       ...
# 3666  3666           NaN     04/04/2020  NaN    NaN                       NaN
# 3667  3667           NaN     04/04/2020  NaN    NaN                       NaN
# 3668  3668           NaN     04/04/2020  NaN    NaN                       NaN
# 3669  3669           NaN     04/04/2020  NaN    NaN                       NaN
# 3670  3670           NaN     04/04/2020  NaN    NaN                       NaN
#
# ...

# %%
#data2.loc[data2["Confirmed"]==748,:]
data2.loc[data2["Confirmed"]==321,:]
#data2.loc[data2["Confirmed"]==571,:]
#data2.loc[data2["Confirmed"]==523,:]
#data2.loc[data2["Confirmed"]==503,:]
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 704  705  06/04/20  6:00 PM            Telengana                       -
# 734  735  07/04/20  9:00 AM            Telengana                       -
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# 704                        -     34       7        321
# 734                        -     34       7        321

# %%
len(set(data7['lab']))
# Out:
# 266

# %%
data2
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0      1  30/01/20  6:00 PM               Kerala                       1
# 1      2  31/01/20  6:00 PM               Kerala                       1
# 2      3  01/02/20  6:00 PM               Kerala                       2
# 3      4  02/02/20  6:00 PM               Kerala                       3
# 4      5  03/02/20  6:00 PM               Kerala                       3
# ..   ...       ...      ...                  ...                     ...
# 734  735  07/04/20  9:00 AM            Telengana                       -
# 735  736  07/04/20  9:00 AM              Tripura                       -
# 736  737  07/04/20  9:00 AM          Uttarakhand                       -
# 737  738  07/04/20  9:00 AM        Uttar Pradesh                       -
# 738  739  07/04/20  9:00 AM          West Bengal                       -
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
data5.detected_city.value_counts()
# Out:
# Mumbai             67
# Bengaluru          41
# Kasaragod          26
# Pune               25
# Nizamuddin area    24
#                    ..
# Sonepat             1
# Amritsar            1
# Bhilai              1
# Sankoo Valley       1
# Aurangabad          1
# Name: detected_city, Length: 234, dtype: int64
