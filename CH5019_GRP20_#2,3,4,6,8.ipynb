# %%
import pandas as pd
import numpy as num
from matplotlib import pyplot as plt

# %%
states = pd.read_csv('IndividualDetails.csv')

# %%
df = states.iloc[:7599]

# %%
df.detected_district.value_counts()[:30].plot(kind ='bar')

# %%
df.detected_district.value_counts()[30:60].plot(kind ='bar')

# %%
df.detected_district.value_counts()[60:100].plot(kind ='bar')

# %%
df.detected_district.value_counts()[100:138].plot(kind ='bar')

# %%
df.detected_district.value_counts()[:30]
# Out:
# Mumbai                 1008
# Pune                    248
# Indore                  235
# Hyderabad               225
# Jaipur                  221
# Ahmedabad               197
# Chennai                 172
# Kasaragod               164
# Thane                   119
# Bhopal                  116
# Agra                     88
# Coimbatore               86
# Kurnool                  76
# Kannur                   64
# Bengaluru Urban          62
# Gautam Buddha Nagar      62
# Erode                    60
# Vadodara                 59
# Guntur                   58
# Tirunelveli              58
# Dindigul                 54
# Evacuees*                50
# Nizamabad                49
# S.P.S. Nellore           48
# S.A.S. Nagar             48
# Srinagar                 46
# Meerut                   44
# Jodhpur                  43
# Mysuru                   42
# Prakasam                 41
# Name: detected_district, dtype: int64

# %%
df.detected_district.value_counts()[30:60]
# Out:
# Theni              41
# Namakkal           41
# Khordha            40
# Chengalpattu       39
# Bandipora          39
# Nuh                38
# Tiruchirappalli    36
# Ranipet            36
# Krishna            35
# Gurugram           32
# Jhunjhunu          31
# Siwan              29
# Baramulla          29
# Y.S.R. Kadapa      29
# Lucknow            29
# Bhilwara           28
# Faridabad          28
# Palwal             28
# Jaisalmer          27
# Viluppuram         27
# Tonk               27
# Surat              27
# Tiruppur           26
# Sangli             26
# South Delhi        26
# Madurai            25
# Ahmednagar         25
# Nagpur             25
# Ghaziabad          25
# Banswara           24
# Name: detected_district, dtype: int64

# %%
df.detected_district.value_counts()[60:100]
# Out:
# Thoothukkudi                 24
# Ernakulam                    24
# Ranga Reddy                  23
# Bhavnagar                    22
# Karur                        22
# West Godavari                22
# Chittoor                     20
# Malappuram                   20
# Visakhapatnam                20
# Saharanpur                   20
# Bikaner                      20
# Warangal Urban               20
# Jogulamba Gadwal             19
# Jammu                        19
# Kota                         19
# Udhampur                     19
# Shahid Bhagat Singh Nagar    19
# Chandigarh                   19
# Rajkot                       18
# Dehradun                     18
# Karimnagar                   18
# Shamli                       17
# Aurangabad                   17
# East Godavari                17
# Pathanamthitta               16
# Italians*                    16
# Tirupathur                   16
# Anantapur                    15
# Kanyakumari                  15
# ...

# %%
df.detected_district.value_counts()[100:138]
# Out:
# Cuddalore           14
# Barwani             14
# Morena              13
# Thiruvarur          13
# Buldhana            13
# Thrissur            13
# Thiruvallur         13
# Leh                 12
# Nagapattinam        12
# Akola               12
# Jhalawar            12
# Chikkaballapura     12
# Nalgonda            12
# Una                 12
# Kozhikode           12
# Jalandhar           12
# Vellore             11
# Amritsar            11
# Firozabad           11
# Virudhunagar        11
# Dakshina Kannada    11
# Churu               11
# Thanjavur           11
# Kolkata             11
# Mansa               11
# Budgam              11
# Kalaburagi          10
# Ludhiana            10
# Idukki              10
# Sitapur             10
# Kamareddy           10
# Mahabubnagar        10
# Adilabad            10
# Belagavi            10
# South Andaman       10
# Bidar               10
# Korba               10
# Uttara Kannada      10
# Name: detected_district, dtype: int64

# %%
state_df = pd.read_csv('covid_19_india.csv')

# %%
state_df
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 1633  1634  05/05/20  5:00 PM            Telengana                       -
# 1634  1635  05/05/20  5:00 PM              Tripura                       -
# 1635  1636  05/05/20  5:00 PM          Uttarakhand                       -
# 1636  1637  05/05/20  5:00 PM        Uttar Pradesh                       -
# 1637  1638  05/05/20  5:00 PM          West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
Kerala_df = state_df[state_df['State/UnionTerritory'] == 'Kerala']
Kerala_df
Kerala_df[['Cured','Deaths','Confirmed']].plot()
Goa_df = state_df[state_df['State/UnionTerritory'] == 'Goa']
Goa_df
Goa_df[['Cured','Deaths','Confirmed']].plot()
Delhi_df = state_df[state_df['State/UnionTerritory'] == 'Delhi']
Delhi_df
Delhi_df[['Cured','Deaths','Confirmed']].plot()
AndhraPradesh_df = state_df[state_df['State/UnionTerritory'] == 'AndhraPradesh']
_df
Kerala_df[['Cured','Deaths','Confirmed']].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-023229ba5caa> in <module>
#       9 Delhi_df[['Cured','Deaths','Confirmed']].plot()
#      10 AndhraPradesh_df = state_df[state_df['State/UnionTerritory'] == 'AndhraPradesh']
# ---> 11 _df
#      12 Kerala_df[['Cured','Deaths','Confirmed']].plot()
#      13
#
# NameError: name '_df' is not defined

# %%
import pandas as pd
from matplotlib import pyplot as plt
state_df = pd.read_csv('covid_19_india.csv')
state_df['timestamp'] = pd.to_datetime(state_df.Date, dayfirst=True)
state_df.sort_values(by=['timestamp'])
d = state_df.groupby('timestamp')
df=d.sum()
plt.figure()
df.plot(title="Country Plot")

# %%
state_df
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 1633  1634  05/05/20  5:00 PM            Telengana                       -
# 1634  1635  05/05/20  5:00 PM              Tripura                       -
# 1635  1636  05/05/20  5:00 PM          Uttarakhand                       -
# 1636  1637  05/05/20  5:00 PM        Uttar Pradesh                       -
# 1637  1638  05/05/20  5:00 PM          West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed  timestamp
# ...

# %%
d = state_df.groupby('timestamp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a21e4bfc814c> in <module>
# ----> 1 d = state_df.groupby('timestamp')
#
# NameError: name 'state_df' is not defined

# %%
df = d.sum()

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-848b80e64df8> in <module>
# ----> 1 df.plot()
#
# NameError: name 'df' is not defined

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-848b80e64df8> in <module>
# ----> 1 df.plot()
#
# NameError: name 'df' is not defined

# %%
df['2020-03-01':'2020-04-10'].plot()

# %%
personal_df = pd.read_csv('IndividualDetails.csv')

# %%
personal_df
# Out:
#           id government_id diagnosed_date  age gender  \
# 0          0      KL-TS-P1     30/01/2020   20      F
# 1          1      KL-AL-P1     02/02/2020  NaN    NaN
# 2          2      KL-KS-P1     03/02/2020  NaN    NaN
# 3          3         DL-P1     02/03/2020   45      M
# 4          4         TS-P1     02/03/2020   24      M
# ...      ...           ...            ...  ...    ...
# 27885  27886           NaN     26/04/2020  NaN    NaN
# 27886  27887           NaN     26/04/2020  NaN    NaN
# 27887  27888           NaN     26/04/2020   12      F
# 27888  27889           NaN     26/04/2020   13      F
# 27889  27890           NaN     26/04/2020   17      F
#
#                   detected_city detected_district detected_state nationality  \
# 0                      Thrissur          Thrissur         Kerala       India
# 1                     Alappuzha         Alappuzha         Kerala       India
# 2                     Kasaragod         Kasaragod         Kerala       India
# ...

# %%
personal_df.notes
# Out:
# 0                                     Travelled from Wuhan
# 1                                     Travelled from Wuhan
# 2                                     Travelled from Wuhan
# 3                            Travelled from Austria, Italy
# 4        Travelled from Dubai to Bangalore on 20th Feb,...
#                                ...
# 27885                                      Details awaited
# 27886                                      Details awaited
# 27887                                      Details awaited
# 27888                                      Details awaited
# 27889                                      Details awaited
# Name: notes, Length: 27890, dtype: object

# %%
d = personal_df.groupby('notes')

# %%
df = d.sum()

# %%
df
# Out:
#                                                       id
# notes
#  Mohalla Clinic Doctor (Contact Transmission 80...   672
# (Sec 137) Contact Transmission (Parents found p...   673
# (Sec 150) Husband of P677 (Colleague travelled ...   674
# (Sec 150) Wife of P676                               675
# (foreign travel from UK likely)                      547
# ...                                                  ...
# contacts of earlier positive cases of #COVID19 ...  5080
# locally transmitted                                 1759
# mother&son of a person who earlier tested posit...  2393
# resident of Ram Nagar village in Patiala, Punja...  1013
# travelled to Punjab                                  906
#
# [929 rows x 1 columns]

# %%
df2 = states.detected_state.value_counts()

# %%
df2
# Out:
# Maharashtra                    8068
# Gujarat                        3301
# Delhi                          2918
# Rajasthan                      2185
# Madhya Pradesh                 2090
# Tamil Nadu                     1885
# Uttar Pradesh                  1873
# Andhra Pradesh                 1097
# Telangana                      1001
# West Bengal                     611
# Jammu and Kashmir               523
# Karnataka                       503
# Kerala                          469
# Punjab                          322
# Haryana                         296
# Bihar                           277
# Odisha                          103
# Jharkhand                        82
# Uttarakhand                      51
# Himachal Pradesh                 40
# Chhattisgarh                     37
# Chandigarh                       36
# Assam                            36
# Andaman and Nicobar Islands      33
# Ladakh                           20
# Meghalaya                        12
# ...

# %%
density = [365,308,11297,201,236,555,828,303,312,1029,98,319,859,550,573,1102,269,414,189,123,189,9252,397,46,3,132,2598,394,350,122,17,52]
df2['density'] = density

# %% [markdown]
# df2

# %%
df3 = { 'states' : ['Maharashtra','Gujarat','Delhi','Rajasthan','Madhya Pradesh','Tamil Nadu','Uttar Pradesh','Andhra Pradesh','Telangana','WestBengal','Jammu and Kashmir','Karnataka','Kerala','Punjab','Haryana','Bihar','Odisha','Jharkand','Uttarakhand','Himachal Pradesh','Chattisgarh','Chandigarh','Assam','Andaman and Nicobar islands','Ladakh','Meghalaya','Puducherry','Goa','Tripura','Manipur','Arunachal Pradesh','Mizoram'],'Cases':[8068,3301,2918,2185,2090,1885,1873,1097,1001,611,523,503,469,322,296,277,103,82,51,40,37,36,36,33,20,12,8,7,2,2,1,1], 'density':[365,308,11297,201,236,555,828,303,312,1029,98,319,859,550,573,1102,269,414,189,123,189,9252,397,46,3,132,2598,394,350,122,17,52]         
}
df4 = pd.DataFrame(df3)
df4['intensity'] = df4['Cases']/df4['density']
df4
# Out:
#                          states  Cases  density  intensity
# 0                   Maharashtra   8068      365  22.104110
# 1                       Gujarat   3301      308  10.717532
# 2                         Delhi   2918    11297   0.258299
# 3                     Rajasthan   2185      201  10.870647
# 4                Madhya Pradesh   2090      236   8.855932
# 5                    Tamil Nadu   1885      555   3.396396
# 6                 Uttar Pradesh   1873      828   2.262077
# 7                Andhra Pradesh   1097      303   3.620462
# 8                     Telangana   1001      312   3.208333
# 9                    WestBengal    611     1029   0.593780
# 10            Jammu and Kashmir    523       98   5.336735
# 11                    Karnataka    503      319   1.576803
# 12                       Kerala    469      859   0.545984
# 13                       Punjab    322      550   0.585455
# 14                      Haryana    296      573   0.516579
# ...

# %%
df4.intensity
df4.Cases
# Out:
# 0     8068
# 1     3301
# 2     2918
# 3     2185
# 4     2090
# 5     1885
# 6     1873
# 7     1097
# 8     1001
# 9      611
# 10     523
# 11     503
# 12     469
# 13     322
# 14     296
# 15     277
# 16     103
# 17      82
# 18      51
# 19      40
# 20      37
# 21      36
# 22      36
# 23      33
# 24      20
# 25      12
# 26       8
# 27       7
# 28       2
# 29       2
# 30       1
# 31       1
# Name: Cases, dtype: int64

# %%
df3 = { 'states' : ['Maharashtra','Gujarat','Delhi','Rajasthan','Madhya Pradesh','Tamil Nadu','Uttar Pradesh','Andhra Pradesh','Telangana','WestBengal','Jammu and Kashmir','Karnataka','Kerala','Punjab','Haryana','Bihar','Odisha','Jharkand','Uttarakhand','Himachal Pradesh','Chattisgarh','Chandigarh','Assam','Andaman and Nicobar islands','Ladakh','Meghalaya','Puducherry','Goa','Tripura','Manipur','Arunachal Pradesh','Mizoram'],'Cases':[8068,3301,2918,2185,2090,1885,1873,1097,1001,611,523,503,469,322,296,277,103,82,51,40,37,36,36,33,20,12,8,7,2,2,1,1], 'density':[365,308,11297,201,236,555,828,303,312,1029,98,319,859,550,573,1102,269,414,189,123,189,9252,397,46,3,132,2598,394,350,122,17,52]         
}
df4 = pd.DataFrame(df3)
df4['intensity'] = df4['Cases']/df4['density']
df4
df4.intensity
df4.Cases
plt.plot(df4.intensity)
plt.xlabel("Intensity")
plt.ylabel("No. of Cases")
# Out:
# Text(0, 0.5, 'No. of Cases')

# %%
df5 = personal_df.notes.value_counts()

# %%
df5[:50]
# Out:
# Details awaited                                                                                            23180
# Travelled to Delhi                                                                                           863
# Details Awaited                                                                                              377
# Travelled from Dubai                                                                                          99
# Local Transmission                                                                                            92
# Contact of Positive case                                                                                      53
# Contact transmission                                                                                          29
# SARI                                                                                                          27
# ...

# %%
import re

# %%
personal_df.notes
# Out:
# 0                                     Travelled from Wuhan
# 1                                     Travelled from Wuhan
# 2                                     Travelled from Wuhan
# 3                            Travelled from Austria, Italy
# 4        Travelled from Dubai to Bangalore on 20th Feb,...
#                                ...
# 27885                                      Details awaited
# 27886                                      Details awaited
# 27887                                      Details awaited
# 27888                                      Details awaited
# 27889                                      Details awaited
# Name: notes, Length: 27890, dtype: object

# %%
df5[50:100].sum()
# Out:
# 252

# %%
df5[100:150]
# Out:
# Contact of  Bapu Dham Patient                                                           4
# No Info                                                                                 4
# Travelled from Saudi Arabia, Details awaited                                            4
# Travelled from US                                                                       4
# Contact of same family                                                                  4
# All contacts of Bambooflat family                                                       4
# Resident of Nanjangud - Working with P52                                                4
# Contact Transmission P 531                                                              4
# Travel history of Delhi                                                                 4
# Contact patient                                                                         4
# ...

# %%
df5[150:200].sum()
# Out:
# 112

# %%
s = personal_df.groupby('detected_state')

# %%
df6 = s.get_group('Maharashtra')

# %%
df6
# Out:
#           id government_id diagnosed_date  age gender detected_city  \
# 43        43           NaN     09/03/2020  NaN      M          Pune
# 44        44           NaN     09/03/2020  NaN      F          Pune
# 59        59           NaN     10/03/2020    3      F          Pune
# 60        60           NaN     10/03/2020  NaN    NaN          Pune
# 61        61           NaN     10/03/2020  NaN      M          Pune
# ...      ...           ...            ...  ...    ...           ...
# 27201  27202           NaN     26/04/2020  NaN    NaN           NaN
# 27202  27203           NaN     26/04/2020  NaN    NaN           NaN
# 27203  27204           NaN     26/04/2020  NaN    NaN           NaN
# 27204  27205           NaN     26/04/2020  NaN    NaN           NaN
# 27205  27206           NaN     26/04/2020  NaN    NaN           NaN
#
#       detected_district nationality current_status status_change_date  \
# 43                 Pune       India      Recovered         25/03/2020
# ...

# %%
df6.notes.value_counts()
# Out:
# Details awaited                                                                                           7468
# Details Awaited                                                                                             69
# Related to a previous patient from Sangli                                                                   11
# Details Awaited; Thane division (ex-Mumbai)                                                                 11
# Travelled to Delhi                                                                                           6
#                                                                                                           ...
# Contact transmission                                                                                         1
# Travelled from UAE                                                                                           1
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df6.notes.value_counts()
# Out:
# Details awaited                                                                                           7468
# Details Awaited                                                                                             69
# Related to a previous patient from Sangli                                                                   11
# Details Awaited; Thane division (ex-Mumbai)                                                                 11
# Travelled to Delhi                                                                                           6
# Travel history, details awaited                                                                              5
# Contact Transmission                                                                                         4
# First contacts or family members of the group of 40 who came back from Dubai earlier                         4
# ...

# %%
df7.notes.value_counts()
# Out:
# Details awaited                                                                                           3143
# Local Transmission                                                                                          89
# Travelled to Delhi                                                                                           6
# Visited Rajasthan                                                                                            6
# Local Positive Contact                                                                                       5
# Details Awaited                                                                                              5
# Travelled from Saudi Arabia                                                                                  5
# Visited Delhi                                                                                                3
# ...

# %%
s.get_group('Delhi').notes.value_counts()
# Out:
# Details awaited                                                            2445
# Travelled to Delhi                                                           34
# Details Awaited                                                              26
# Details awaited; MoHFW reported 26 on 21 Mar AM                               4
# No Travel History ( details awaited)                                          4
# Daughter of P171                                                              2
# Travelled from UK                                                             2
# Mother of P171                                                                1
#  Mohalla Clinic Doctor (Contact Transmission 800+ contacts quarantined)       1
# Travelled from London                                                         1
# Travelled from Mexico                                                         1
# Travelled from Austria, Italy                                                 1
# ...

# %%
s.get_group('Rajasthan').notes.value_counts()
# Out:
# Details awaited                                                                                            1868
# Details Awaited                                                                                              56
# Have identified contact history                                                                              25
# Travelled to Delhi                                                                                           24
# Contacts of first positive in Ramganj                                                                        13
# Travelled from Iran, Resident of Ladakh( AIIMS ) - Evacuee                                                    9
# Travelled from Iran, Resident of Ladakh( S.N Medical College ) - Evacuee                                      9
# Family member of Patient, ID Unknown                                                                          8
# ...

# %%
s.get_group('Rajasthan').notes.value_counts()
# Out:
# Details awaited                                                                                            1868
# Details Awaited                                                                                              56
# Have identified contact history                                                                              25
# Travelled to Delhi                                                                                           24
# Contacts of first positive in Ramganj                                                                        13
# Travelled from Iran, Resident of Ladakh( AIIMS ) - Evacuee                                                    9
# Travelled from Iran, Resident of Ladakh( S.N Medical College ) - Evacuee                                      9
# Family member of Patient, ID Unknown                                                                          8
# ...

# %%
s.get_group('Madhya Pradesh').notes.value_counts()
# Out:
# Details awaited                                                                                               1951
# Details Awaited                                                                                                 39
# Relative of Dubai-returned couple                                                                               10
# contacts of earlier positive cases of #COVID19 & have no travel history                                          5
# Details awaited, (family)                                                                                        3
# Travelled from Dubai and Thailand(Family)                                                                        3
# Travelled from Dubai.                                                                                            2
# BSF officer                                                                                                      1
# ...

# %%
s.get_group('Maharashtra').notes.value_counts()
# Out:
# Details awaited                                                                                           7468
# Details Awaited                                                                                             69
# Related to a previous patient from Sangli                                                                   11
# Details Awaited; Thane division (ex-Mumbai)                                                                 11
# Travelled to Delhi                                                                                           6
# Travel history, details awaited                                                                              5
# Contact Transmission                                                                                         4
# First contacts or family members of the group of 40 who came back from Dubai earlier                         4
# ...

# %%
s.get_group('Gujarat').notes.value_counts()
# Out:
# Details awaited                                                                                           3143
# Local Transmission                                                                                          89
# Travelled to Delhi                                                                                           6
# Visited Rajasthan                                                                                            6
# Local Positive Contact                                                                                       5
# Details Awaited                                                                                              5
# Travelled from Saudi Arabia                                                                                  5
# Visited Delhi                                                                                                3
# ...

# %%
top_states =  {'Location':['India','Delhi','Rajasthan','Madhya Pradesh','Mahrashtra','Gujarat'],'primary_cases':[238,15,44,8,49,23],'secondary_cases':[1036,36,75,11,22,16],'teritay_cases':[344,8,45,13,27,118]}

# %%
top_states_df = pd.DataFrame(top_states)

# %%
top_states_df
# Out:
#          Location  primary_cases  secondary_cases  teritay_cases
# 0           India            238             1036            344
# 1           Delhi             15               36              8
# 2       Rajasthan             44               75             45
# 3  Madhya Pradesh              8               11             13
# 4      Mahrashtra             49               22             27
# 5         Gujarat             23               16            118

# %%
top_states_df.plot(kind = 'bar')
